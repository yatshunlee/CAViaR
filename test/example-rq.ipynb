# %%
# Author: Lee Yat Shun, Jasper
# Copyright (c) 2023 Lee Yat Shun, Jasper. All rights reserved.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from caviar import CaviarModel
from backtesting import backtest
from var_tests import binomial_test, kupiec_pof_test, christoffersen_test

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('../data/SPY.xlsx')
df.columns = df.iloc[5].values
df = df.iloc[6:].iloc[::-1].reset_index(drop=True)
df['Log Return'] = df.PX_LAST.apply(lambda x: np.log(x)).diff()
df = df.set_index('Date')
df.head()
# Out:
#             PX_LAST Change % Change  PX_OPEN Change % Change  PX_HIGH Change  \
# Date
# 1993-01-29  25.2238    NaN      NaN  25.2417    NaN      NaN  25.2417    NaN
# 1993-02-01  25.4032    NaN      NaN  25.2417    NaN      NaN  25.4032    NaN
# 1993-02-02   25.457    NaN      NaN  25.3852    NaN      NaN  25.4749    NaN
# 1993-02-03  25.7261    NaN      NaN  25.4929    NaN      NaN   25.744    NaN
# 1993-02-04  25.8337    NaN      NaN  25.8158    NaN      NaN  25.8876    NaN
#
#            % Change   PX_LOW Change % Change  Log Return
# Date
# 1993-01-29      NaN  25.1161    NaN      NaN         NaN
# 1993-02-01      NaN  25.2417    NaN      NaN    0.007087
# 1993-02-02      NaN  25.3314    NaN      NaN    0.002116
# 1993-02-03      NaN  25.4749    NaN      NaN    0.010515
# 1993-02-04      NaN   25.762    NaN      NaN    0.004174

# %%
returns = df['Log Return'].dropna()
low_open_log_difference = (df['PX_LOW'].apply(lambda x: np.log(x)) - df['PX_OPEN'].apply(lambda x: np.log(x))).dropna()

# %%
in_samples = returns['2001':'2015'] * 100
out_of_samples = returns['2016':] * 100

# %%
# initiate parameter
quantile = 0.05 # 5% VAR

# %%
# instantiation
caviar_model = CaviarModel(quantile, model='igarch', method='RQ')
caviar_model
# Out:
# CaviarModel(quantile=0.05, model=igarch, method=numeric, G=10, tol=1e-10, LAGS=4)

# %%
caviar_model.fit(in_samples)
# Out:
# Generating 5 best initial betas out of 5000...
# Optimizing...
# when m = 1
# Update 0: 0.12712130842338162
# Update 1: 0.12682049402006243
# Update 2: 0.1268204938157245
# Update 3: 0.12682049366831968
# Update 4: 0.12682049354557887
# Update 5: 0.12682049343358612
# Fail for the initialized beta. Skip.
# when m = 2
# Update 0: 0.12722817267157177
# Update 1: 0.1268214779494475
# Update 2: 0.12682139747530222
# Update 3: 0.12682139747530222
# when m = 3
# Update 0: 0.12759903667542385
# Update 1: 0.1268228343893439
# Update 2: 0.12682267620837145
# Update 3: 0.12682267620837145
# when m = 4
# Update 0: 0.12769548892745203
# Update 1: 0.12682106344285324
# Update 2: 0.12682105074985434
# Update 3: 0.12682104780191228
# Update 4: 0.12682104730373173
# Update 5: 0.12682104729678992
# when m = 5
# Update 0: 0.127718104558083
# Update 1: 0.12682093014814438
# Update 2: 0.12682093014814438
# Final loss: 0.12682049343200782
# Time taken(s): 22.12

# %%
caviar_model.summary()
# Out:
#        coefficient  S.E. of beta  pval of beta
# beta1     0.036347      0.024002  6.497154e-02
# beta2     0.916868      0.012983  0.000000e+00
# beta3     0.227257      0.032869  2.355017e-12

# %% [markdown]
# ### Backtesting on the out of samples

# %%
# in sample
caviar_model.plot_caviar(in_samples, 'in')

# %%
# out of sample
caviar_model.plot_caviar(out_of_samples, 'out')

# %%
caviar_model.plot_news_impact_curve(VaR=-1.645)

# %% [markdown]
# ### VaR Test

# %%
in_VaR = caviar_model.predict(in_samples, caviar_model.VaR0_in)

# %%
out_VaR = caviar_model.predict(out_of_samples, caviar_model.VaR0_out)

# %%
(out_of_samples < out_VaR[:-1]).value_counts(normalize=True)
# Out:
# False    0.9595
# True     0.0405
# Name: Log Return, dtype: float64

# %%
# The null hypothesis states that the current VaR violations are uncorrelated with past violations.

print(caviar_model.dq_test(in_samples, 'in'))
print(caviar_model.dq_test(out_of_samples, 'out'))
# Out:
# 0.6225409609089145
# 0.9982310734622377

# %%
# H0: the obs ~ binomial(p)

print(binomial_test(in_samples, in_VaR[:-1], caviar_model.quantile))
print(binomial_test(out_of_samples, out_VaR[:-1], caviar_model.quantile))
# Out:
# 0.9693038363544069
# 0.051130907172270285

# %%
# H0: the observed failure rate is equal to the failure rate suggested by the confidence interval.

print(kupiec_pof_test(in_samples, in_VaR[:-1], caviar_model.quantile))
print(kupiec_pof_test(out_of_samples, out_VaR[:-1], caviar_model.quantile))
# Out:
# 1.0
# 1.0

# %%
# null hypothesis: the observations are independent of each other

print(christoffersen_test(in_samples, in_VaR[:-1]))
print(christoffersen_test(out_of_samples, out_VaR[:-1]))
# Out:
# 0.023867200463391802
# 0.9399899750296284

# %% [markdown]
# ### Forecast (totally unknown)

# %%
if len(out_VaR)-1 == len(out_of_samples):
    print('Day T+1 VaR forecast:', out_VaR[-1])
# Out:
# Day T+1 VaR forecast: -1.9321312982438095

# %% [markdown]
# ### Mean reversion property?

# %%
the_following_day = np.array(range(2000))[out_of_samples < out_VaR[:-1]] + 1

print(out_of_samples.iloc[the_following_day].describe())
print((out_of_samples.iloc[the_following_day]/100 + 1).cumprod())

out_of_samples.iloc[the_following_day].plot.hist()
# Out:
# count    81.000000
# mean      0.279405
# std       1.874275
# min      -4.301879
# 25%      -0.421039
# 50%       0.215315
# 75%       1.042455
# max       8.202780
# Name: Log Return, dtype: float64
# Date
# 2015-03-09    1.004136
# 2015-03-11    1.001783
# 2015-03-26    0.999394
# 2015-06-30    1.001484
# 2015-07-09    1.003294
#                 ...
# 2022-06-17    1.257841
# 2022-08-23    1.254794
# 2022-08-29    1.246469
# 2022-09-14    1.251217
# 2022-12-16    1.236358
# Name: Log Return, Length: 81, dtype: float64
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Backtesting

# %%
out_low_open_log_difference = low_open_log_difference.loc[out_of_samples.index]
(out_low_open_log_difference * 100 < out_VaR[:-1]).value_counts(normalize=True)
# Out:
# False    0.9455
# True     0.0545
# dtype: float64

# %%
# with 0.2% transaction cost

backtest(out_of_samples, out_low_open_log_difference, out_VaR[:-1], caviar_model.quantile, ntl=100, penalty=0.002)
